// %%
// Question 1 What data type is each of the following?
5 Integer
5.0 Double
5 > 1 Boolean
'5'  String
5 * 2  Integer
'5' * 2 Integer
 '5' + '2' Integer
 5 / 2 Integer
5 % 2 Integer
 {5, 2, 1} int[]
 5 == 3 Boolean
Pi (the number) Double

// %%
//Question 2 Part a

string word="Supercalifragilisticexpialidocious";
Console.WriteLine(word.Length);
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-31216.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
// ...

// %%
//Question 2 Part b
string word="Supercalifragilisticexpialidocious";
Console.WriteLine(word.Contains("ice"));
// Out:
// True

// %%
//Question 2 Part c
String a="Supercalifragilisticexpialidocious";
String b= "Honorificabilitudinitatibus";
String c="Bababadalgharaghtakamminarronnkonn";
int a_len=a.Length;
int b_len=b.Length;
int c_len=c.Length;
if(a_len>b_len && a_len>c_len )
{
    Console.WriteLine(a);
}
else if(b_len>c_len && b_len>a_len)
    {
    Console.WriteLine(b);
}
else
{
    Console.WriteLine(c);
}
// Out:
// Bababadalgharaghtakamminarronnkonn

// %%
//Question 2 part d
var names = new SortedSet<string>();
          names.Add("Berlioz");
          names.Add("Borodin");
          names.Add("Brian");
          names.Add("Bartok");
          names.Add("Bellini");
          names.Add("Buxtehude");
          names.Add("Bernstein");
            Console.WriteLine("First element in the dictionary will be" + names.First());
            Console.WriteLine("last element in the dictionary will be" + names.Last());
// Out:
// First element in the dictionary will beBartok
// last element in the dictionary will beBuxtehude

// %%
//Question 3
public class Function
{
    public static void Main(string[] args)
    {
      int a;
        Console.WriteLine("Enter the side a of the triangle");
         a=int.Parse(Console.ReadLine());
         Console.WriteLine("Enter the side b of the triangle");
        int b=int.Parse(Console.ReadLine());
         Console.WriteLine("Enter the side c of the triangle");
       int c=int.Parse(Console.ReadLine());
        double result = triangleArea(a, b, c);
        Console.WriteLine(result);
   
    static double triangleArea(double a, double b, double c)
    {
        
        double s = (a + b + c) / 2;

       
        double area = Math.Sqrt(s * (s - a) * (s - b) * (s - c));

        return area;
    }
}
}/* OUTPUT
Enter the side a of the triangle
3
Enter the side b of the triangle
2
Enter the side c of the triangle
4
2.90473750965556
*/

// %%
// Question 4 
public class OddEven
{
    public static void Main(string[] args)
    {
        int x=0,y=0;
        Console.WriteLine("Enter number of elements to be stored");
        int n=int.Parse(Console.ReadLine());
        int[] arr = new int[100];   
        int[] even = new int[100];   
        int[] odd = new int[100];   
        for(int i=0;i<n;i++)
        {
            Console.WriteLine("Enter the element in pos" +i);
            arr[i]=int.Parse(Console.ReadLine());
            if(arr[i]%2==0)
            {
                even[x++]=arr[i];
            }
            else
            {
                odd[y++]=arr[i];
            }
        }
        for (int i = 0; i < n; i++)
        {
            Console.WriteLine("element"+i +": "+arr[i]);
        }
        Console.Write("Even elements are: ");
        for(int i=0;i<x;i++)
        {
            Console.Write(" "+even[i]);
        }
        Console.WriteLine("\n");
        Console.Write("Odd elements are: ");
        for(int i=0;i<y;i++)
        {
            Console.Write(" "+odd[i]);
        }
    }
}
/* OUTPUT
Enter number of elements to be stored
5
Enter the element in pos0
1
Enter the element in pos1
2
Enter the element in pos2
3

Enter the element in pos3
4

Enter the element in pos4
5

element0: 1
element1: 2
element2: 3
element3: 4
element4: 5
Even elements are:  2 4

Odd elements are:  1 3 5
*/

// %%
//Question 5 part a
class Program
{
    static void Main()
    {
       
        Console.WriteLine("Enter the x coordinate");
        double x=double.Parse(Console.ReadLine());
        Console.WriteLine("Enter the y coordinate");
        double y=double.Parse(Console.ReadLine());
        Console.WriteLine("Enter the x coordinate of lower left corner");
        double x1=double.Parse(Console.ReadLine());
        Console.WriteLine("Enter the y coordinate of lower left corner");
        double y1=double.Parse(Console.ReadLine());
        Console.WriteLine("Enter the x coordinate of upper right corner");
        double x2=double.Parse(Console.ReadLine());
        Console.WriteLine("Enter the y coordinate of upper right corner");
        double y2=double.Parse(Console.ReadLine());
        bool result = inside(x,y,x1,y1,x2,y2);
        Console.WriteLine(result);
        
        
      // Question 5 part b
        if(inside(1,1,0.3,0.5,1.1,0.7)==true &&inside(1,1,0.5,0.2,1.1,2)==true)
        {
            Console.WriteLine("The coordinare (1,1) lies inside both the rectangles");
        }
        else
        {
             Console.WriteLine("The coordinare (1,1) does not lies inside both the rectangles");
        }// Output: True
    }

    static bool inside(double x, double y, double x1, double y1, double x2, double y2)
    {
        // Check if (x, y) is inside the rectangle
        return x > x1 && x < x2 && y > y1 && y < y2;
    }
}
/*
Enter the x coordinate
2

Enter the y coordinate
2
Enter the x coordinate of lower left corner
0.5
Enter the y coordinate of lower left corner
0.4
Enter the x coordinate of upper right corner
3
Enter the y coordinate of upper right corner
3

True


Question 5 part b
The coordinare (1,1) does not lies inside both the rectangles
*/
